# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('perrin-freres-monthly-champagne-.csv')
df.head(5)
# Out:
#      Month  Perrin Freres monthly champagne sales millions ?64-?72
# 0  1964-01                                             2815.0
# 1  1964-02                                             2672.0
# 2  1964-03                                             2755.0
# 3  1964-04                                             2721.0
# 4  1964-05                                             2946.0

# %%
df.tail()
# Out:
#                                                  Month  \
# 102                                            1972-07
# 103                                            1972-08
# 104                                            1972-09
# 105                                                NaN
# 106  Perrin Freres monthly champagne sales millions...
#
#      Perrin Freres monthly champagne sales millions ?64-?72
# 102                                             4298.0
# 103                                             1413.0
# 104                                             5877.0
# 105                                                NaN
# 106                                                NaN

# %% [markdown]
# # step 1 - cleaning data

# %%
df.columns=['Month','Sales']
df.head()
# Out:
#      Month   Sales
# 0  1964-01  2815.0
# 1  1964-02  2672.0
# 2  1964-03  2755.0
# 3  1964-04  2721.0
# 4  1964-05  2946.0

# %%
# drop last two rows
df.drop(106,axis=0,inplace=True)

# %%
df.drop(105,axis=0,inplace=True)

# %%
df.tail()
# Out:
#        Month   Sales
# 100  1972-05  4618.0
# 101  1972-06  5312.0
# 102  1972-07  4298.0
# 103  1972-08  1413.0
# 104  1972-09  5877.0

# %%
# convert month column to datetime format from string
df['Month']=pd.to_datetime(df['Month'])

# %%
df.head()
# Out:
#        Month   Sales
# 0 1964-01-01  2815.0
# 1 1964-02-01  2672.0
# 2 1964-03-01  2755.0
# 3 1964-04-01  2721.0
# 4 1964-05-01  2946.0

# %%
df.set_index('Month',inplace=True)

# %%
df.head()
# Out:
#              Sales
# Month
# 1964-01-01  2815.0
# 1964-02-01  2672.0
# 1964-03-01  2755.0
# 1964-04-01  2721.0
# 1964-05-01  2946.0

# %%
df.describe()
# Out:
#               Sales
# count    105.000000
# mean    4761.152381
# std     2553.502601
# min     1413.000000
# 25%     3113.000000
# 50%     4217.000000
# 75%     5221.000000
# max    13916.000000

# %% [markdown]
# # step 2 - visualize the data

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # Dickey-Fuller Test

# %%
## testing for stationarity
# %pip install statsmodels
from statsmodels.tsa.stattools import adfuller
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
test_result=adfuller(df['Sales'])

# %%
## H0 : It is non stationary
## H1 : It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels=['ADF Test Statistic','p-value','#Lags Used','Number of Observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value))
    if result[1] <= 0.05:
        print('strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is statinry')
    else:
        print('weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary')

# %%
adfuller_test(df['Sales'])
# Out:
# ADF Test Statistic : -1.8335930563276195
# p-value : 0.3639157716602467
# #Lags Used : 11
# Number of Observations used : 93
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# # Differencing -> to make it stationary

# %%
df['Sales First Difference']=df['Sales']-df['Sales'].shift(1)

# %%
df['Sales']
# Out:
# Month
# 1964-01-01    2815.0
# 1964-02-01    2672.0
# 1964-03-01    2755.0
# 1964-04-01    2721.0
# 1964-05-01    2946.0
#                ...
# 1972-05-01    4618.0
# 1972-06-01    5312.0
# 1972-07-01    4298.0
# 1972-08-01    1413.0
# 1972-09-01    5877.0
# Name: Sales, Length: 105, dtype: float64

# %%
df['Sales'].shift(1)
# Out:
# Month
# 1964-01-01       NaN
# 1964-02-01    2815.0
# 1964-03-01    2672.0
# 1964-04-01    2755.0
# 1964-05-01    2721.0
#                ...
# 1972-05-01    4788.0
# 1972-06-01    4618.0
# 1972-07-01    5312.0
# 1972-08-01    4298.0
# 1972-09-01    1413.0
# Name: Sales, Length: 105, dtype: float64

# %%
df['Seasonal First Difference']=df['Sales']-df['Sales'].shift(12)

# %%
df.head(10)
# Out:
#              Sales  Seasonal First Difference  Sales First Difference
# Month
# 1964-01-01  2815.0                        NaN                     NaN
# 1964-02-01  2672.0                        NaN                  -143.0
# 1964-03-01  2755.0                        NaN                    83.0
# 1964-04-01  2721.0                        NaN                   -34.0
# 1964-05-01  2946.0                        NaN                   225.0
# 1964-06-01  3036.0                        NaN                    90.0
# 1964-07-01  2282.0                        NaN                  -754.0
# 1964-08-01  2212.0                        NaN                   -70.0
# 1964-09-01  2922.0                        NaN                   710.0
# 1964-10-01  4301.0                        NaN                  1379.0

# %%
## again test dickey fulller test
adfuller_test(df['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -7.626619157213166
# p-value : 2.0605796968136632e-11
# #Lags Used : 0
# Number of Observations used : 92
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is statinry

# %%
df['Seasonal First Difference'].plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # Auto Regressive Model
# $$Y_t = c + \phi_1 Y_{t-1} + \phi_2 Y_{t-2} + \dots + \phi_p Y_{t-p} + \epsilon_t$$

# %%
import statsmodels.api as sm

# %%
# auto co-relation and partial- auto co-relation
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig=plt.figure(figsize=(12,8))
ax1=fig.add_subplot(211)
fig=sm.graphics.tsa.plot_acf(df['Seasonal First Difference'].iloc[13:],lags=40,ax=ax1)
ax2=fig.add_subplot(212)
fig=sm.graphics.tsa.plot_pacf(df['Seasonal First Difference'].iloc[13:],lags=40,ax=ax2)

# %%
# For non-seasonal data
#p=1, d=1, q=0 or 1
# p= AR // d= I // q=MA 
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(df['Sales'],order=(1,1,1))
model_fit=model.fit()
# Out:
# C:\Users\prave\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\prave\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\prave\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Sales   No. Observations:                  105
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -952.814
# Date:                Sun, 26 Apr 2026   AIC                           1911.627
# Time:                        11:07:21   BIC                           1919.560
# Sample:                    01-01-1964   HQIC                          1914.841
#                          - 09-01-1972
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4545      0.114      3.999      0.000       0.232       0.677
# ma.L1         -0.9666      0.056    -17.316      0.000      -1.076      -0.857
# sigma2      5.226e+06   6.17e+05      8.473      0.000    4.02e+06    6.43e+06
# ...

# %%
df['forecast']=model_fit.predict(start=90,end=103,dynamic=True)
df[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %%
## the previous arimax doesn't work as expected for seasonal data, so we're using seasonal-arima {sarima}

# %%
model=sm.tsa.statespace.SARIMAX(df['Sales'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
# Out:
# C:\Users\prave\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\prave\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
df['forecast']=results.predict(start=90,end=103,dynamic=True)
df[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Sales Seasonal First Difference Sales First Difference forecast
# 1974-04-01   NaN                       NaN                    NaN      NaN
# 1974-05-01   NaN                       NaN                    NaN      NaN
# 1974-06-01   NaN                       NaN                    NaN      NaN
# 1974-07-01   NaN                       NaN                    NaN      NaN
# 1974-08-01   NaN                       NaN                    NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])
# Out:
# C:\Users\prave\AppData\Local\Temp\ipykernel_33776\1723908026.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 104, end = 120, dynamic= True)  
future_df[['Sales', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >
